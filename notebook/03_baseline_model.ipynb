# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

df = pd.read_csv("cleaned_crmls_sold.csv")

train_df = df[df['is_test'] == 0].copy()
test_df = df[df['is_test'] == 1].copy()

feature_cols = [col for col in df.columns if col not in ['target_log_price', 'is_test']]

X_train = train_df[feature_cols]
y_train = train_df['target_log_price']

X_test = test_df[feature_cols]
y_test = test_df['target_log_price']

# %%
# linear regression
baseline_model = LinearRegression()

baseline_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Evaluation
y_pred_log = baseline_model.predict(X_test)

# R2 value
r2 = r2_score(y_test, y_pred_log)

# RMSE, MSE
rmse_log = np.sqrt(mean_squared_error(y_test, y_pred_log))
mae_log = mean_absolute_error(y_test, y_pred_log)

print("=" * 50)
print("📈 Baseline Model (Linear Regression)")
print(f"  - R² Score : {r2:.4f}")
print(f"  - RMSE    : {rmse_log:.4f}")
print(f"  - MAE    : {mae_log:.4f}")
print("=" * 50)
# Out:
# ...
# 📈 Baseline Model (Linear Regression)
#   - R² Score : 0.3535
#   - RMSE    : 0.5499
#   - MAE    : 0.4339
# ...

# %%
y_test_original = np.expm1(y_test)
y_pred_original = np.expm1(y_pred_log)

mae_dollars = mean_absolute_error(y_test_original, y_pred_original)
print(f"MAE dollor: ${mae_dollars:,.2f}")
# Out:
# MAE dollor: $906,764.03

# %%
from sklearn.metrics import median_absolute_error

# Median value
medae_dollars = median_absolute_error(y_test_original, y_pred_original)
print(f"Median AE: ${medae_dollars:,.2f}")
# Out:
# Median AE: $343,557.35
